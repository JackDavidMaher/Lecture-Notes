# %% [markdown]
# # 2024
# ## 1.
# ### a)
# $$ Z(T,C,U) = \int_{-\infty}^{\infty} dE W(E,C,U) e^{-\beta E} $$
# $$ Z(T,C,U) = \int_{-\infty}^{\infty} dE \int_{-\infty}^{\infty} \frac{dQ}{q_0} \delta (E - H_0(Q)) e^{- \beta E} $$
# $$ Z(T,C,U) = \int_{-\infty}^{\infty} \frac{dQ}{q_0} \int_{-\infty}^{\infty} dE \delta (E - H_0(Q)) e^{- \beta E} $$
# $$ Z(T,C,U) = \int_{-\infty}^{\infty} \frac{dQ}{q_0} \exp \left(- \beta H_0(Q)\right) $$
# $$ Z(T,C,U) = \int_{-\infty}^{\infty} \frac{dQ}{q_0} \exp \left[ -\beta \left(\frac{Q^2}{2C}-QU\right) \right]$$
# ### b)
# $$ Z(T,C,U) = \int_{-\infty}^{\infty} \frac{dQ}{q_0} \exp \left[ -\beta \left(\frac{Q^2}{2C}-QU\right) \right]$$
# $$ Z(T,C,U) = \frac{1}{q_0} \left( \int_{-\infty}^{\infty} e^{(-\beta \frac{(Q-CU)^2-C^2U^2}{2C})} \right) $$
# $$ Z(T,C,U) = \frac{1}{q_0} e^{ \frac{ \beta C U^2}{2}} \int_{-\infty}^{\infty} e^{-\beta \frac{(Q-CU)^2}{2C}} dQ $$
# $$ Z(T,C,U) = \frac{1}{q_0} e^{ \frac{ \beta C U^2}{2}} \int_{-\infty}^{\infty} e^{-\frac{\beta}{2C} (Q-CU)^2} dQ $$
# $ Q-CU = x $, $ dQ = dx $
# $$ Z(T,C,U) = \frac{1}{q_0} e^{ \frac{ \beta C U^2}{2}} \int_{-\infty}^{\infty} e^{-\frac{1}{2Ck_B T} x^2} dx $$
# $$ Z(T,C,U) = \frac{1}{q_0} e^{ \frac{ \beta C U^2}{2}} \sqrt{2 \pi C k_B T} $$
# $$ Z(T,C,U) = \sqrt{\frac{2 \pi C k_B T}{q_0^2}} e^{ \frac{ \beta C U^2}{2}} $$
