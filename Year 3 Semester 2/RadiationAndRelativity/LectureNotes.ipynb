# %% [markdown]
# # Mon 19th January
#
# Electromagnetism is naturally relativistic
#
# There are differences in how the course was taught over the years.

# %% [markdown]
# ### Newtonian Mechanics
#
# Newtons Laws:
# 1. A particle moves at a constant velocity (when resultant force = 0)
# 2. Relationship between acceleration and external force is $F = m \frac{d^2r}{dt^2} = ma$
# 3. Forces of action and reaction are equal magnitude and opposite direction
#
# Galilean transformations:
# 1.  $r'=r-vt$
# 2.  $t'=t$
#
# This means that the laws of motion are the same in all inertial frames.

# %% [markdown]
# # Mon 26th January
# ### Lorentz Transformations
#
# Like literally just that
#
# Invarient type shit

# %% [markdown]
# # Tue 27th January
#
# $ s_{12}^2 < 0 $ is called timelike
#
# $ s_{12}^2 > 0 $ is called spacelike
#
# $ s_{12}^2 = 0 $ is called lightlike or null
#
# For a timellike case $s_{12}^2 = c^2 T_{12}^2$
#
# ### Minkowski Spacetime Diagram
# The present only exists for you. The past exists for everyone. The future exists for no one.
#
# Elsewhere is outside the light cone. Events in elsewhere cannot influence or be influenced by the event at the origin.

# %% [markdown]
# # Fri 30th January
#
# ### Non-Assessed Problem Sheet 1
#
# 1.1) i. $ct_1=1,x_1=1$ $$ct'=\gamma (ct-\beta x) = \frac{5}{3}(1-\frac{4}{5}*1) = \frac{1}{3}$$ $$x'=\gamma (x - \beta ct) = \frac{5}{3}(1-\frac{4}{5}*1) = \frac{1}{3}$$
# On the light cone (Equal to each other)
#
# ii. $ct_2=0,x_2=1$ $$ct'=\gamma (ct-\beta x) = \frac{5}{3}(0-\frac{4}{5}*1) = -\frac{4}{3}$$ $$x'=\gamma (x - \beta ct) = \frac{5}{3}(1-0) = \frac{5}{3}$$
# Outside the light cone (Spacelike) ($x'>ct'$)
#
# iii. $ct_3=-2,x_3=1$ $$ct'=\gamma (ct-\beta x) = \frac{5}{3}(-2-\frac{4}{5}*1) = -\frac{14}{3}$$ $$x'=\gamma (x - \beta ct) = \frac{5}{3}(1-\frac{4}{5}*-2) = \frac{13}{3}$$
# Inside the light cone (Timelike) ($x'<ct'$)

# %% [markdown]
# # Mon 2nd February
# ### 3d Vectors
# orthonormal basis: {$\hat{e}_1, \hat{e}_2, \hat{e}_3$} = {$\hat{e}_i$} where
# $$\hat{e}_i . \hat{e}_j = \delta_{ij} = 1 (if i=j) = 0 (else)$$

# %% [markdown]
# # Tue 3rd February
# ### Non-orthogonal Basis
#
# {$\underline{e}_i$} non-orthogonal basis vectors. i=1,2,3
#
# Linearly independent i.e. no vector can be written as a linear combination of the others.
#
# Geometrically not co-planar (not in the same plane) i.e. $\underline{e}_1 \cdot (\underline{e}_2 \times \underline{e}_3) \neq 0$
#
# $\underline{e}_i \cdot \underline{e}_j(\neq \delta_{ij}) = g_{ij}$

# %% [markdown]
# # Fri 6th February
# ### Non-Assessed Problem Sheet 1 (continued)
# 1.5)
# $$\underline e_1 = x, \underline e_2 = y, \underline e_3 = z $$
# $$\delta_{i1} = \underline e_i . \underline e_1 = (1,0,0)$$
# $$\delta_{1i} = \underline e_1 . \underline e_i = (1,0,0)$$
# $$\delta_{i2} = \underline e_i . \underline e_2 = (0,1,0)$$
# $$\delta_{i3} = \underline e_3 . \underline e_i = (0,0,1)$$
#
# $$\delta_{i1} = \delta_{1i} = \bold{\hat{x}}$$
# $$\delta_{i2} = \bold{\hat{y}}$$
# $$\delta_{i3} = \bold{\hat{z}}$$
#
# $$\delta_{1i}\delta_{2i} = (1,0,0).(0,1,0) = 0$$
# $$\delta_{i2} v_i = (0,1,0) . (v_1,v_2,v_3) = v_2$$

# %% [markdown]
# # Mon 9th February
# ### 4d Vectors (4-vectors)
# {$ \underline{e_0}, \underline{e_1}, \underline{e_2}, \underline{e_3}$} = {$ \underline{e_\mu} $} where $\mu = 0,1,2,3$
# $$ A = A_\mu \underline{e}^\mu $$

# %% [markdown]
# # Fri 27th February
# 45149194
# ### Non-Assessed Problem Sheet 2
# 2.6 i.  $(a \times b) \cdot (c \times d) = (a \times b)_i \cdot (c \times d)_i = \epsilon_{ijk} a_j b_k \epsilon_{ilm} c_l d_m = \epsilon_{ijk} \epsilon_{ilm} a_j b_k c_l d_m$
# $$ = (\delta_{kl} \delta_{jm} - \delta_{km} \delta_{jl}) a_j b_k c_l d_m $$
# $$ = a_j b_k c_k d_j - a_j b_k c_j d_k = (a . c)(b . d) - (a . d)(b . c) $$
# ii.  $$ [(a \times b) \times (c \times d)]_i = \epsilon_{ijk} (a \times b)_j (c \times d)_k = \epsilon_{ijk} \epsilon_{jlm} a_l b_m \epsilon_{knp} c_n d_p $$
# $$ = \epsilon_{ijk} \epsilon_{jlm} \epsilon_{knp} a_l b_m c_n d_p = \epsilon_{jki} \epsilon_{jlm} \epsilon_{knp} a_l b_m c_n d_p $$
# $$ = (\delta_{kl} \delta_{im} - \delta_{km} \delta_{il}) a_l b_m \epsilon_{knp} c_n d_p $$
# $$ = a_k b_i \epsilon_{knp} c_n d_p - a_i b_k \epsilon_{knp} c_n d_p $$
# $$ = (a \cdot (c \times d)) b_i - a_i (b \cdot (c \times d)) $$
