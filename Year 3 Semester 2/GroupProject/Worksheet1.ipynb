# %%
import numpy as np
# 1) i)
RStar = 0.2162
delta = 0.0072
RPlanet = RStar * np.sqrt(delta)
print(f"Planetary Radius: {RPlanet * 109} Radius of Earth")
# 1) ii)
T=500
KB = 1.380649e-23
mu = 2
mp = 1.6726219e-27
G = 6.67430e-11
Mp = 5 * 5.972e24
Rp = 2 * 6.371e6
g = G * Mp / Rp**2
H = (KB * T) / (mu * mp * g)
#print(f"Scale Height: {H} m")
delta = (2 * Rp * 5 * H) / ((RStar*6.96e8) ** 2)
print(f"Change in Transit Depth: {np.round(delta*100,4)}%")
# Out:
# Planetary Radius: 1.9996244380903132 Radius of Earth
# Change in Transit Depth: 0.0946%

# %%
#2) i)
